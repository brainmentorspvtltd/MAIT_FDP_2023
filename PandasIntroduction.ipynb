# %% [markdown]
# <a href="https://colab.research.google.com/github/brainmentorspvtltd/MAIT_FDP_2023/blob/main/PandasIntroduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("Dataset_Sales.xlsx")

# %%
df.shape
# Out:
# (15000, 17)

# %%
df.head()
# Out:
#    Order ID Order Date   Unit Cost   Price  Order Qty  Cost of Sales  \
# 0      7077 2013-03-18   76.094968  304.00          9     684.854710
# 1       117 2012-02-23    7.491753   12.99          4      29.967011
# 2      7018 2012-01-11   10.122338  159.99          9      91.101039
# 3       140 2014-02-13    0.576153   25.69         18      10.370759
# 4       491 2013-01-17  108.508777  304.00          9     976.578991
#
#        Sales       Profit Channel                  Promotion Name  \
# 0  2714.7200  2029.865290   Store       European Spring Promotion
# 1    50.1414    20.174389   Store       European Spring Promotion
# 2  1395.1128  1304.011761   Store       European Spring Promotion
# 3   462.4200   452.049241   Store  North America Spring Promotion
# 4  2614.4000  1637.821009  Online          Asian Spring Promotion
#
#                                      Product Name       Manufacturer  \
# 0                    Contoso SLR Camera M143 Grey       Contoso, Ltd
# ...

# %%
df.describe()
# Out:
#            Order ID     Unit Cost         Price     Order Qty  Cost of Sales  \
# count  15000.000000  15000.000000  15000.000000  15000.000000   15000.000000
# mean   11209.316600    124.425132    296.514697     16.741733    1586.954833
# std     6451.583877    163.569912    345.985232     43.490032    2408.961430
# min        1.000000      0.001576      0.950000      4.000000       0.015756
# 25%     5629.750000     16.847345     59.000000      9.000000     189.677420
# 50%    11238.500000     69.688876    205.000000     10.000000     752.752320
# 75%    16789.500000    164.348636    366.000000     13.000000    2006.030237
# max    22352.000000   1896.133845   2899.990000   1560.000000   42991.137192
#
#               Sales        Profit
# count  15000.000000  15000.000000
# mean    3692.783986   2105.829152
# std     4917.886955   3387.145437
# min        4.750000   -838.426733
# 25%      645.000000    242.198732
# 50%     2301.175750   1012.683637
# ...

# %%
# check how many null values are there

# %%
df.isna().sum()
# Out:
# Order ID                0
# Order Date              0
# Unit Cost               0
# Price                   0
# Order Qty               0
# Cost of Sales           0
# Sales                   0
# Profit                  0
# Channel                 0
# Promotion Name          0
# Product Name            0
# Manufacturer            0
# Product Sub Category    0
# Product Category        0
# Region                  0
# City                    0
# Country                 0
# dtype: int64

# %%
# df['City' == np.nan]
