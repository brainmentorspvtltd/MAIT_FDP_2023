# %% [markdown]
# <a href="https://colab.research.google.com/github/brainmentorspvtltd/MAIT_FDP_2023/blob/main/MultipleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("NSE_Data.csv")

# %%
df.head()
# Out:
#           Date      Open      High       Low     Close  Shares Traded  \
# 0  02-Aug-2021  15874.90  15892.90  15834.65  15885.15      244847433
# 1  03-Aug-2021  15951.55  16146.90  15914.35  16130.75      341289658
# 2  04-Aug-2021  16195.25  16290.20  16176.15  16258.80      427337644
# 3  05-Aug-2021  16288.95  16349.45  16210.30  16294.60      418174517
# 4  06-Aug-2021  16304.40  16336.75  16223.30  16238.20      320087281
#
#    Turnover (Rs. Cr)
# 0           20766.99
# 1           26373.24
# 2           32434.78
# 3           31386.78
# 4           24716.17

# %%
df.tail()
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 224  27-Jun-2022  15926.20  15927.45  15815.50  15832.05      210932505
# 225  28-Jun-2022  15757.45  15892.10  15710.15  15850.20      251865155
# 226  29-Jun-2022  15701.70  15861.60  15687.80  15799.10      444949551
# 227  30-Jun-2022  15774.50  15890.00  15728.85  15780.25      306027777
# 228  01-Jul-2022  15703.70  15793.95  15511.05  15752.05      364090131
#
#      Turnover (Rs. Cr)
# 224           17770.42
# 225           18419.75
# 226           22528.57
# 227           23970.65
# 228           25891.94

# %%
df.shape
# Out:
# (229, 7)

# %%
X = df.iloc[:,1:4]
y = df['Close']

# %%
X[:3]
# Out:
#        Open     High       Low
# 0  15874.90  15892.9  15834.65
# 1  15951.55  16146.9  15914.35
# 2  16195.25  16290.2  16176.15

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
x_train.shape
# Out:
# (183, 3)

# %%
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(x_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2273.7993459519303

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9954371999216516
